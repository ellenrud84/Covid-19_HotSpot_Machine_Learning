# %%
import pandas as pd

# %%
file = "2020_US_Region_Mobility_Report.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  US  United States          NaN          NaN         NaN
# 1                  US  United States          NaN          NaN         NaN
# 2                  US  United States          NaN          NaN         NaN
# 3                  US  United States          NaN          NaN         NaN
# 4                  US  United States          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code       date  \
# 0             NaN               NaN  2/15/2020
# 1             NaN               NaN  2/16/2020
# 2             NaN               NaN  2/17/2020
# 3             NaN               NaN  2/18/2020
# 4             NaN               NaN  2/19/2020
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                6.0
# 1                                                7.0
# 2                                                6.0
# 3                                                0.0
# 4                                                2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                2.0
# 1                                                1.0
# 2                                                0.0
# 3                                               -1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                15.0
# 1                                16.0
# 2                                28.0
# 3                                 6.0
# 4                                 8.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                            2.0
# 2                                           -9.0
# 3                                            1.0
# 4                                            1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      0.0
# 2                                    -24.0
# 3                                      0.0
# 4                                      1.0
#
#    residential_percent_change_from_baseline
# 0                                      -1.0
# 1                                      -1.0
# 2                                       5.0
# 3                                       1.0
# 4                                       0.0

# %%
mobility_df = df.loc[:,["census_fips_code","retail_and_recreation_percent_change_from_baseline",
                        "grocery_and_pharmacy_percent_change_from_baseline","parks_percent_change_from_baseline",
                        "transit_stations_percent_change_from_baseline","workplaces_percent_change_from_baseline",
                        "residential_percent_change_from_baseline"]]

# %%
mobility_df
# Out:
#         census_fips_code  retail_and_recreation_percent_change_from_baseline  \
# 0                    NaN                                                6.0
# 1                    NaN                                                7.0
# 2                    NaN                                                6.0
# 3                    NaN                                                0.0
# 4                    NaN                                                2.0
# ...                  ...                                                ...
# 581567           56045.0                                                NaN
# 581568           56045.0                                                NaN
# 581569           56045.0                                                NaN
# 581570           56045.0                                                NaN
# 581571           56045.0                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 581567                                                NaN
# 581568                                                NaN
# 581569                                                NaN
# 581570                                                NaN
# 581571                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 581567                                 NaN
# 581568                                 NaN
# 581569                                 NaN
# 581570                                 NaN
# 581571                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 581567                                            NaN
# 581568                                            NaN
# 581569                                            NaN
# 581570                                            NaN
# 581571                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 581567                                    -22.0
# 581568                                    -15.0
# 581569                                    -19.0
# 581570                                    -14.0
# 581571                                    -12.0
#
#         residential_percent_change_from_baseline
# 0                                           -1.0
# 1                                           -1.0
# 2                                            5.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 581567                                       NaN
# 581568                                       NaN
# 581569                                       NaN
# 581570                                       NaN
# 581571                                       NaN
#
# [581572 rows x 7 columns]

# %%
df.to_csv('Mobility_1.csv')
